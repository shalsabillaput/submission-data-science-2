# %% [markdown]
# # Project Preparation

# %% [markdown]
# Library Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# # Data Preparation

# %% [markdown]
# # Data Loading and Cleaning

# %%
df = pd.read_csv('data.csv', sep=";")

# %% [markdown]
# check sampel data

# %%
df.head()
# Out:
#    Marital_status  Application_mode  Application_order  Course
# 0               1                17                  5     171  \
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime_evening_attendance  Previous_qualification
# 0                           1                       1  \
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           0                       1
#
#    Previous_qualification_grade  Nacionality  Mothers_qualification
# 0                         122.0            1                     19  \
# 1                         160.0            1                      1
# ...

# %% [markdown]
# melihat informasi data

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Marital_status                                4424 non-null   int64
#  1   Application_mode                              4424 non-null   int64
#  2   Application_order                             4424 non-null   int64
#  3   Course                                        4424 non-null   int64
#  4   Daytime_evening_attendance                    4424 non-null   int64
#  5   Previous_qualification                        4424 non-null   int64
#  6   Previous_qualification_grade                  4424 non-null   float64
#  7   Nacionality                                   4424 non-null   int64
#  8   Mothers_qualification                         4424 non-null   int64
# ...

# %%
print("Jumlah Baris:", df.shape[0])
# Out:
# Jumlah Baris: 4424

# %% [markdown]
# check missing value

# %%
df.isnull().sum()
# Out:
# Marital_status                                  0
# Application_mode                                0
# Application_order                               0
# Course                                          0
# Daytime_evening_attendance                      0
# Previous_qualification                          0
# Previous_qualification_grade                    0
# Nacionality                                     0
# Mothers_qualification                           0
# Fathers_qualification                           0
# Mothers_occupation                              0
# Fathers_occupation                              0
# Admission_grade                                 0
# Displaced                                       0
# Educational_special_needs                       0
# Debtor                                          0
# Tuition_fees_up_to_date                         0
# Gender                                          0
# Scholarship_holder                              0
# ...

# %% [markdown]
# check duplicated value

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# melihat deskripsi statistik dari data

# %%
df.describe()
# Out:
#        Marital_status  Application_mode  Application_order       Course
# count     4424.000000       4424.000000        4424.000000  4424.000000  \
# mean         1.178571         18.669078           1.727848  8856.642631
# std          0.605747         17.484682           1.313793  2063.566416
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         57.000000           9.000000  9991.000000
#
#        Daytime_evening_attendance  Previous_qualification
# count                 4424.000000             4424.000000  \
# mean                     0.890823                4.577758
# std                      0.311897               10.216592
# min                      0.000000                1.000000
# ...

# %% [markdown]
# melihat persentase bedasarkan variabel target

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Status', data=df, palette='viridis', order = df['Status'].value_counts().index)
plt.title('Distribusi Status Mahasiswa (Target)')
plt.xlabel('Status')
plt.ylabel('Jumlah Mahasiswa')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
print("\nFrekuensi Status Mahasiswa:")
print(df['Status'].value_counts(normalize=True) * 100)
# Out:
# Frekuensi Status Mahasiswa:
# Status
# Graduate    49.932188
# Dropout     32.120253
# Enrolled    17.947559
# Name: proportion, dtype: float64

# %% [markdown]
# jumlah mahasiswa yang dropout sangatlah banyak, hampir sekitar 30% dari total semua mahasiswa

# %% [markdown]
# analisis univariat

# %% [markdown]
# fitur numerikal

# %%
numerical_features = ['Age_at_enrollment', 'Admission_grade',
                      'Curricular_units_1st_sem_approved', 'Curricular_units_1st_sem_grade',
                      'Curricular_units_2nd_sem_approved', 'Curricular_units_2nd_sem_grade',
                      'Unemployment_rate', 'Inflation_rate', 'GDP']

# %%
for feature in numerical_features:
    if feature in df.columns:
        plt.figure(figsize=(10, 4))

        plt.subplot(1, 2, 1)
        sns.histplot(df[feature], kde=True, bins=30)
        plt.title(f'Distribusi {feature}')

        plt.subplot(1, 2, 2)
        sns.boxplot(y=df[feature])
        plt.title(f'Boxplot {feature}')

        plt.tight_layout()
        plt.show()
    else:
        print(f"Kolom '{feature}' tidak ditemukan dalam dataset.")

# %% [markdown]
# banyak mahasiswa yang mendaftar di umur 20 - 30, admission grade kebanyakan di sekitar 120 - 140, ada banyak mahasiswa yang tidak memiliki unit kurikuler di semsetar pertama

# %% [markdown]
# fitur kategorikal

# %%
categorical_features_to_plot = ['Course', 'Gender', 'Scholarship_holder', 'Debtor', 'Daytime_evening_attendance']

# %%
for feature in categorical_features_to_plot:
    if feature in df.columns:
        plt.figure(figsize=(10, 6))
        # Jika jumlah kategori terlalu banyak, tampilkan top N saja
        if df[feature].nunique() > 15:
            top_n = df[feature].value_counts().nlargest(15)
            sns.barplot(x=top_n.index, y=top_n.values, palette='Spectral', order=top_n.index)
            plt.title(f'Distribusi Top 15 Kategori untuk {feature}')
            plt.xlabel(f'{feature} (Top 15)')
        else:
            sns.countplot(x=feature, data=df, palette='Spectral', order = df[feature].value_counts().index)
            plt.title(f'Distribusi {feature}')
            plt.xlabel(feature)

        plt.ylabel('Jumlah Mahasiswa')
        plt.xticks(rotation=45, ha='right')
        plt.tight_layout()
        plt.show()
    else:
        print(f"Kolom '{feature}' tidak ditemukan dalam dataset.")

# %% [markdown]
# course yang paling banyak diambil adalah course nomor 9500, kebanyakan mahasiswa perempuan, mahasiswa yang menghutang lebih sedikit dengan yang tidak, kebanyakan mahasiswa menghadiri kuliah di siang hari, ada sekitar 1000 mahasiswa yang memegang beasiswa

# %% [markdown]
# analisis bivariat

# %%
print("\n--- Analisis Bivariat (dengan Status) ---")
if 'Status' in df.columns:
    # Fitur Kategorikal vs. Status
    categorical_vs_status = ['Course', 'Gender', 'Scholarship_holder', 'Debtor', 'Tuition_fees_up_to_date', 'Marital_status']
    for feature in categorical_vs_status:
        if feature in df.columns:
            plt.figure(figsize=(12, 7))
            if df[feature].nunique() > 10: # Jika kategori banyak, mungkin lebih baik crosstab atau fokus pada beberapa kategori
                # Untuk fitur dengan banyak kategori seperti 'Course', kita bisa fokus pada beberapa course teratas
                # atau membuat tabel silang (crosstab)
                print(f"\nAnalisis {feature} vs Status (mungkin perlu penanganan khusus karena banyak kategori)")
                # Contoh: Crosstab untuk Course (tampilkan persentase)
                if feature == 'Course':
                    try:
                        # Ambil 5 course paling umum
                        top_courses = df['Course'].value_counts().nlargest(5).index
                        df_top_courses = df[df['Course'].isin(top_courses)]
                        sns.countplot(x=feature, hue='Status', data=df_top_courses, palette='pastel', order=top_courses)
                        plt.title(f'{feature} (Top 5) vs. Status')
                    except Exception as e:
                        print(f"Error plotting {feature}: {e}")
                        # Fallback jika ada error
                        pd.crosstab(df[feature], df['Status'], normalize='index').plot(kind='bar', stacked=True, figsize=(14,8))
                        plt.title(f'Proporsi Status berdasarkan {feature} (Normalized)')

                else: # Untuk fitur kategorikal lain dengan kategori tidak terlalu banyak
                     sns.countplot(x=feature, hue='Status', data=df, palette='pastel', order = df[feature].value_counts().index)
                     plt.title(f'{feature} vs. Status')

            else:
                sns.countplot(x=feature, hue='Status', data=df, palette='pastel', order = df[feature].value_counts().index)
                plt.title(f'{feature} vs. Status')

            plt.xlabel(feature)
            plt.ylabel('Jumlah Mahasiswa')
            plt.xticks(rotation=45, ha='right')
            plt.legend(title='Status')
            plt.tight_layout()
            plt.show()
        else:
            print(f"Kolom '{feature}' tidak ditemukan untuk analisis bivariat.")

    # Fitur Numerik vs. Status
    numerical_vs_status = ['Age_at_enrollment', 'Admission_grade',
                           'Curricular_units_1st_sem_approved', 'Curricular_units_1st_sem_grade',
                           'Curricular_units_2nd_sem_approved', 'Curricular_units_2nd_sem_grade',
                           'Unemployment_rate', 'Inflation_rate', 'GDP']
    for feature in numerical_vs_status:
        if feature in df.columns:
            plt.figure(figsize=(10, 6))
            sns.boxplot(x='Status', y=feature, data=df, palette='coolwarm')
            plt.title(f'{feature} vs. Status')
            plt.xlabel('Status')
            plt.ylabel(feature)
            plt.xticks(rotation=45)
            plt.tight_layout()
            plt.show()

            plt.figure(figsize=(10, 6))
            sns.violinplot(x='Status', y=feature, data=df, palette='coolwarm')
            plt.title(f'Violin Plot: {feature} vs. Status')
            plt.xlabel('Status')
            plt.ylabel(feature)
            plt.xticks(rotation=45)
            plt.tight_layout()
            plt.show()
        else:
            print(f"Kolom '{feature}' tidak ditemukan untuk analisis bivariat.")
else:
    print("Kolom 'Status' tidak ditemukan. Analisis bivariat dengan target tidak dapat dilakukan.")
# Out:
# --- Analisis Bivariat (dengan Status) ---
#
# Analisis Course vs Status (mungkin perlu penanganan khusus karena banyak kategori)

# %% [markdown]
# persentase dimana mahasiswa laki laki dropout lebih besar daripada mahasiswa wanita, persentase mahasiswa yang menghutang droput lebih besar ketimbang yang tidak menghutang, mahasiswa yang tuition date fee nya tidak up to date kebanyakan droput, kebanyakan mahasiswa yang dropout tidak memiliki pasangan (single),  mahasiswa yang memiliki beasiswa cenderung akan lulus, semseter 1 dan 2 sepertinya menjadi faktor penentu yang utama dalam menentukan apakah mahasiswa akan dropout atau tidak

# %% [markdown]
# # Export Dataset

# %% [markdown]
# mengirim dataset ke supabase

# %%
URL = "postgresql://postgres:dicodinggaming@db.glwnzxtvnwsvghakfiga.supabase.co:5432/postgres"
 
engine = create_engine(URL)
df.to_sql('students_performance', engine)
# Out:
# 124

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# split dataset

# %%
from sklearn.model_selection import train_test_split
 
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42, shuffle=True)
train_df.reset_index(drop=True, inplace=True)
test_df.reset_index(drop=True, inplace=True)
 
print(train_df.shape)
print(test_df.shape)
# Out:
# (3539, 37)
# (885, 37)

# %% [markdown]
# cek distribusi target

# %%
sns.countplot(data=train_df, x="Status")
plt.show()

# %% [markdown]
# dapat dilihat data tidak seimbang sehingga perlu dilakukan data augmentation, disini yang dilakukan adalah oversampling

# %% [markdown]
# data oversampling

# %% [markdown]
# jumlah data kelas

# %%
train_df.Status.value_counts()
# Out:
# Status
# Graduate    1791
# Dropout     1105
# Enrolled     643
# Name: count, dtype: int64

# %%
df_majority = train_df[(train_df.Status == "Graduate")]
df_minority_1 = train_df[(train_df.Status == "Dropout")]
df_minority_2 = train_df[(train_df.Status == "Enrolled")]

# %% [markdown]
# resampling

# %%
from sklearn.utils import resample
 
df_minority_1_oversampled = resample(df_minority_1, n_samples=1791, random_state=42)
df_minority_2_oversampled = resample(df_minority_2, n_samples=1791, random_state=42)
print(df_minority_1_oversampled.shape)
print(df_minority_2_oversampled.shape)
# Out:
# (1791, 37)
# (1791, 37)

# %% [markdown]
# menggabungkan data yang sudah disampling

# %%
from sklearn.utils import shuffle
 
oversampled_train_df = pd.concat([df_majority, df_minority_1_oversampled]).reset_index(drop=True)
oversampled_train_df = pd.concat([oversampled_train_df, df_minority_2_oversampled]).reset_index(drop=True)
oversampled_train_df = shuffle(oversampled_train_df, random_state=42)
oversampled_train_df.reset_index(drop=True, inplace=True)
oversampled_train_df.sample(5)
# Out:
#       Marital_status  Application_mode  Application_order  Course
# 4093               2                 7                  1    9130  \
# 1295               2                39                  1    9991
# 4177               1                39                  1    9991
# 389                1                 1                  3    9500
# 4423               1                39                  1    9991
#
#       Daytime_evening_attendance  Previous_qualification
# 4093                           1                       3  \
# 1295                           0                       1
# 4177                           0                       1
# 389                            1                       1
# 4423                           0                       1
#
#       Previous_qualification_grade  Nacionality  Mothers_qualification
# 4093                         140.0            1                      5  \
# 1295                         133.1            1                     37
# ...

# %% [markdown]
# cek df

# %%
sns.countplot(data=oversampled_train_df, x="Status")
plt.show()

# %% [markdown]
# encoding dan scaling

# %% [markdown]
# memisahkan fitur dan target

# %%
X_train = oversampled_train_df.drop(columns="Status", axis=1)
y_train = oversampled_train_df["Status"]
 
X_test = test_df.drop(columns="Status", axis=1)
y_test = test_df["Status"]

# %% [markdown]
# helper function menyimpan encoder dan scaler

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
import joblib
 
def scaling(features, df, df_test=None):
    if df_test is not None:
        df = df.copy()
        df_test = df_test.copy()
        for feature in features:
            scaler = MinMaxScaler()
            X = np.asanyarray(df[feature])
            X = X.reshape(-1,1)
            scaler.fit(X)
            df["{}".format(feature)] = scaler.transform(X)
            joblib.dump(scaler, "model/scaler_{}.joblib".format(feature))
            
            X_test = np.asanyarray(df_test[feature])
            X_test = X_test.reshape(-1,1)
            df_test["{}".format(feature)] = scaler.transform(X_test)
        return df, df_test
    else:
        df = df.copy()
        for feature in features:
            scaler = MinMaxScaler()
            X = np.asanyarray(df[feature])
            X = X.reshape(-1,1)
            scaler.fit(X)
            df["{}".format(feature)] = scaler.transform(X)
            joblib.dump(scaler, "model/scaler_{}.joblib".format(feature))
        return df
 
def encoding(features, df, df_test=None):
    if df_test is not None:
        df = df.copy()
        df_test = df_test.copy()
        for feature in features:
            encoder = LabelEncoder()
            encoder.fit(df[feature])
            df["{}".format(feature)] = encoder.transform(df[feature])
            joblib.dump(encoder, "model/encoder_{}.joblib".format(feature))

            df_test["{}".format(feature)] = encoder.transform(df_test[feature])
        return df, df_test
    else:
        df = df.copy()
        for feature in features:
            encoder = LabelEncoder()
            encoder.fit(df[feature])
            df["{}".format(feature)] = encoder.transform(df[feature])
            joblib.dump(encoder, "model/encoder_{}.joblib".format(feature))
        return df

# %% [markdown]
# menyimpan encoder dan scaler

# %%
numerical_columns = [
    'Application_order',
    'Previous_qualification_grade',
    'Admission_grade',
    'Age_at_enrollment',
    'Curricular_units_1st_sem_credited',
    'Curricular_units_1st_sem_enrolled',
    'Curricular_units_1st_sem_evaluations',
    'Curricular_units_1st_sem_approved',
    'Curricular_units_1st_sem_grade',
    'Curricular_units_1st_sem_without_evaluations',
    'Curricular_units_2nd_sem_credited',
    'Curricular_units_2nd_sem_enrolled',
    'Curricular_units_2nd_sem_evaluations',
    'Curricular_units_2nd_sem_approved',
    'Curricular_units_2nd_sem_grade',
    'Curricular_units_2nd_sem_without_evaluations',
    'Unemployment_rate',
    'Inflation_rate',
    'GDP',
]

categorical_columns = [
    'Marital_status',
    'Application_mode',
    'Course',
    'Daytime_evening_attendance',
    'Previous_qualification',
    'Nacionality',
    'Mothers_qualification',
    'Fathers_qualification',
    'Mothers_occupation',
    'Fathers_occupation',
    'Displaced',
    'Educational_special_needs',
    'Debtor',
    'Tuition_fees_up_to_date',
    'Gender',
    'Scholarship_holder',
    'International',
]

# %% [markdown]
# fitur numerik

# %%
new_train_df, new_test_df = scaling(numerical_columns, X_train, X_test)

# %% [markdown]
# fitur kategorik

# %% [markdown]
# tidak perlu encoding karena dari awal data sudah di encode

# %%
# new_train_df, new_test_df = encoding(categorical_columns, new_train_df, new_test_df)

# %% [markdown]
# encoding fitur target

# %%
encoder = LabelEncoder()
encoder.fit(y_train)
new_y_train = encoder.transform(y_train)
joblib.dump(encoder, "model/encoder_target.joblib")
 
new_y_test = encoder.transform(y_test)

# %% [markdown]
# PCA

# %% [markdown]
# matriks korelasi

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df[numerical_columns].corr(), annot=True, cmap='jet', linecolor='black', linewidth=1)
plt.show()

# %% [markdown]
# kelompok fitur berkorelasi

# %%
pca_numerical_columns_1 = [
    'Curricular_units_1st_sem_credited',
    'Curricular_units_1st_sem_enrolled',
    'Curricular_units_1st_sem_evaluations',
    'Curricular_units_1st_sem_approved',
    'Curricular_units_1st_sem_grade',
    'Curricular_units_2nd_sem_credited',
    'Curricular_units_2nd_sem_enrolled',
    'Curricular_units_2nd_sem_grade',
    'Curricular_units_2nd_sem_approved',
    'Curricular_units_2nd_sem_evaluations'
]

# %% [markdown]
# dataframe untuk menampung pca

# %%
train_pca_df = new_train_df.copy().reset_index(drop=True)
test_pca_df = new_test_df.copy().reset_index(drop=True)

# %% [markdown]
# pca kelompok feature pertama

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=len(pca_numerical_columns_1), random_state=123)
pca.fit(train_pca_df[pca_numerical_columns_1])
princ_comp = pca.transform(train_pca_df[pca_numerical_columns_1])
 
var_exp = pca.explained_variance_ratio_.round(3)
cum_var_exp = np.cumsum(var_exp)
 
plt.bar(range(len(pca_numerical_columns_1)), var_exp, alpha=0.5, align='center', label='individual explained variance')
plt.step(range(len(pca_numerical_columns_1)), cum_var_exp, where='mid', label='cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal component index')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# mengganti kelompok fitur asli dengan 4 komponen utama dari proses PCA

# %%
pca_1 = PCA(n_components=4, random_state=123)
pca_1.fit(train_pca_df[pca_numerical_columns_1])
joblib.dump(pca_1, "model/pca_{}.joblib".format(1))
princ_comp_1 = pca_1.transform(train_pca_df[pca_numerical_columns_1])
train_pca_df[["pc1_1", "pc1_2", "pc1_3", "pc1_4"]] = pd.DataFrame(princ_comp_1, columns=["pc1_1", "pc1_2", "pc1_3", "pc1_4"])
train_pca_df.drop(columns=pca_numerical_columns_1, axis=1, inplace=True)

# %%
train_pca_df.head(20)
# Out:
#     Marital_status  Application_mode  Application_order  Course
# 0                1                17           0.111111    9238  \
# 1                1                 1           0.111111    9085
# 2                1                 1           0.222222    9853
# 3                1                43           0.111111    9500
# 4                4                39           0.111111    9991
# 5                1                17           0.666667    9500
# 6                1                 1           0.111111    9085
# 7                1                 1           0.333333    9070
# 8                4                39           0.111111    9085
# 9                1                44           0.111111    9003
# 10               1                 7           0.111111    9085
# 11               1                17           0.111111    9500
# 12               1                39           0.111111    9991
# 13               1                17           0.222222    9147
# ...

# %% [markdown]
# melakukan hal yang sama untuk data uji

# %%
test_princ_comp_1 = pca_1.transform(test_pca_df[pca_numerical_columns_1])
test_pca_df[["pc1_1", "pc1_2", "pc1_3", "pc1_4"]] = pd.DataFrame(test_princ_comp_1, columns=["pc1_1", "pc1_2", "pc1_3", "pc1_4"])
test_pca_df.drop(columns=pca_numerical_columns_1, axis=1, inplace=True)
test_pca_df.head()
# Out:
#    Marital_status  Application_mode  Application_order  Course
# 0               4                39           0.111111    9130  \
# 1               1                17           0.111111    9238
# 2               1                17           0.111111    9853
# 3               1                17           0.222222    9670
# 4               1                39           0.111111    9500
#
#    Daytime_evening_attendance  Previous_qualification
# 0                           1                       1  \
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           1                       1
#
#    Previous_qualification_grade  Nacionality  Mothers_qualification
# 0                      0.401053            1                      3  \
# 1                      0.315789            1                      4
# ...

# %% [markdown]
# # Modeling

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
 
tree_model = DecisionTreeClassifier(random_state=123)
 
param_grid = { 
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [5, 6, 7, 8],
    'criterion' :['gini', 'entropy']
}
 
CV_tree = GridSearchCV(estimator=tree_model, param_grid=param_grid, cv=5, n_jobs=-1)
CV_tree.fit(train_pca_df, new_y_train)
# Out:
# d:\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=123),
#              n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 6, 7, 8],
#                          'max_features': ['auto', 'sqrt', 'log2']})

# %% [markdown]
# parameter terbaik

# %%
print("best parameters: ", CV_tree.best_params_)
# Out:
# best parameters:  {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto'}

# %%
tree_model = DecisionTreeClassifier(
    random_state=123,
    criterion='gini', 
    max_depth=8, 
    max_features='auto'
)
 
tree_model.fit(train_pca_df, new_y_train)
joblib.dump(tree_model, "model/tree_model.joblib")
# Out:
# d:\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# ['model/tree_model.joblib']

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
 
rdf_model = RandomForestClassifier(random_state=123)
 
param_grid = { 
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [6, 7, 8],
    'criterion' :['gini', 'entropy']
}
 
CV_rdf = GridSearchCV(estimator=rdf_model, param_grid=param_grid, cv=5, n_jobs=-1)
CV_rdf.fit(train_pca_df, new_y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=123),
#              n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [6, 7, 8],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [200, 500]})

# %%
print("best parameters: ", CV_rdf.best_params_)
# Out:
# best parameters:  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'n_estimators': 200}

# %% [markdown]
# parameter terbaik

# %%
rdf_model = RandomForestClassifier(
    random_state=123, 
    max_depth=8, 
    n_estimators=200, 
    max_features='log2', 
    criterion='entropy', 
    n_jobs=-1
)
rdf_model.fit(train_pca_df, new_y_train)
joblib.dump(rdf_model, "model/rdf_model.joblib")
# Out:
# ['model/rdf_model.joblib']

# %% [markdown]
# Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
 
gboost_model = GradientBoostingClassifier(random_state=123)
 
param_grid = {
    'max_depth': [5, 8],
    'n_estimators': [200, 300],
    'learning_rate': [0.01, 0.1],
    'max_features': ['auto', 'sqrt', 'log2']
}
 
CV_gboost = GridSearchCV(estimator=gboost_model, param_grid=param_grid, cv=5, n_jobs=-1)
CV_gboost.fit(train_pca_df, new_y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(random_state=123),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.1], 'max_depth': [5, 8],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [200, 300]})

# %% [markdown]
# parameter terbaik

# %%
print("best parameters: ", CV_gboost.best_params_)
# Out:
# best parameters:  {'learning_rate': 0.1, 'max_depth': 8, 'max_features': 'log2', 'n_estimators': 300}

# %%
gboost_model = GradientBoostingClassifier(
    random_state=123,
    learning_rate=0.1, 
    max_depth=8, 
    max_features='log2',
    n_estimators=300
)
gboost_model.fit(train_pca_df, new_y_train)
joblib.dump(gboost_model, "model/gboost_model.joblib")
# Out:
# ['model/gboost_model.joblib']

# %% [markdown]
# # Evaluasi

# %% [markdown]
# helper function evaluasi model

# %%
from sklearn.metrics import classification_report, confusion_matrix
 
def evaluating(y_pred, y_true):
    '''Evaluasi model'''
    labels=['Dropout', 'Graduate', 'Enrolled']
    
    print(classification_report(y_pred=y_pred, y_true=y_true))
    
    cnf_matrix = confusion_matrix(y_pred=y_pred, y_true=y_true, labels=labels)
    confusion_matrix_df = pd.DataFrame(cnf_matrix, labels, labels)
    sns.heatmap(confusion_matrix_df, annot=True, annot_kws={'size': 14}, fmt='d', cmap='YlGnBu')
    plt.ylabel('True label', fontsize=15)
    plt.xlabel('Predicted label', fontsize=15)
    plt.show()
    
    return confusion_matrix_df

# %% [markdown]
# decision tree

# %%
y_pred_test = tree_model.predict(test_pca_df)
y_pred_test = encoder.inverse_transform(y_pred_test)

evaluating(y_pred=y_pred_test, y_true=y_test)
# Out:
#               precision    recall  f1-score   support
#
#      Dropout       0.78      0.61      0.68       316
#     Enrolled       0.33      0.51      0.40       151
#     Graduate       0.78      0.76      0.77       418
#
#     accuracy                           0.66       885
#    macro avg       0.63      0.63      0.62       885
# weighted avg       0.70      0.66      0.68       885
#           Dropout  Graduate  Enrolled
# Dropout       193        45        78
# Graduate       25       317        76
# Enrolled       30        44        77

# %% [markdown]
# random forest

# %%
y_pred_test = rdf_model.predict(test_pca_df)
y_pred_test = encoder.inverse_transform(y_pred_test)
 
evaluating(y_pred=y_pred_test, y_true=y_test)
# Out:
#               precision    recall  f1-score   support
#
#      Dropout       0.88      0.67      0.76       316
#     Enrolled       0.39      0.59      0.47       151
#     Graduate       0.80      0.80      0.80       418
#
#     accuracy                           0.72       885
#    macro avg       0.69      0.69      0.68       885
# weighted avg       0.76      0.72      0.73       885
#           Dropout  Graduate  Enrolled
# Dropout       211        41        64
# Graduate        9       334        75
# Enrolled       20        42        89

# %% [markdown]
# gradient boost

# %%
y_pred_test = gboost_model.predict(test_pca_df)
y_pred_test = encoder.inverse_transform(y_pred_test)
 
evaluating(y_pred=y_pred_test, y_true=y_test)
# Out:
#               precision    recall  f1-score   support
#
#      Dropout       0.84      0.69      0.76       316
#     Enrolled       0.47      0.38      0.42       151
#     Graduate       0.76      0.91      0.83       418
#
#     accuracy                           0.74       885
#    macro avg       0.69      0.66      0.67       885
# weighted avg       0.74      0.74      0.73       885
#           Dropout  Graduate  Enrolled
# Dropout       218        55        43
# Graduate       13       382        23
# Enrolled       27        66        58
